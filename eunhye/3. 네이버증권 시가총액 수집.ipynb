# %% [markdown]
# 1. 필요한 라이브러리 import
# 2. 특정 웹페이지의 정보를 가져오라고 요청
# 3. 응답된 데이터가 많아요 -> html내용만 필요하다
# 4. 받아온 html은 거대한 String... -> 파싱
# 5. 많은 태그들을 가지고 있는 상태
# 6. 특정 선택자에 해당하는 요소들만 빼서 리스트화
# 7. 리스트 안에 들어있는건... "요소" 우리가 필요한건,,, "content"  -> 가공`

# %% [markdown]
# # 네이버 증권 - 시가총액 데이터 수집
# ## 종목명만 리스트에 저장
# ## ['삼성', '구글', '애플', ...]

# %%
import requests as req

# %%
from bs4 import BeautifulSoup as bs

# %%
res= req.get("https://finance.naver.com/sise/sise_market_sum.naver")

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '\n\n\n\n\n\n\n<!--  global include -->\n\n\t\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<title>시가총액 : 네이버페이 증권</title>\n\t\t\t\n\t\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버페이 증권" />\n\n\n\n\n\n\t\n    \n        <meta property="og:url" content="http://finance.naver.com/sise/sise_market_sum.naver"/>\n        \n\t\t\t\n\t\t    \n\t\t    \t<meta property="og:title" content="시가총액 : 네이버페이 증권"/>\n\t\t     \n\t\t\n\t\t\n\t\t\t\n\t\t\t   <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>\n\t\t    \n\t\t    \n\t\t\n\t\t \n\t\t\t\n\t\t\t    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t    \n\t\t    \n\t\t\n    \n\n<meta property="og:type" conten
# ...

# %%
#응답받은 많은 정보 중, html 내용만 다시 한번 선택
# 다시 선택한 데이터는 하나의 String으로 합쳐져 있음 
#거대한 String을 태그를 이해할 수 있는 형태로 가공 
soup = bs(res.text, "lxml")

# %%
soup
# Out:
# <html lang="ko">
# <head>
# <title>네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title"/>
# <meta content="네이버페이 증권" property="og:title"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250411170222/css/finance_header.css" rel="stylesheet" type="text/css"/>
# ...

# %%
stock = soup.select("a.tltle")
price = soup.select("td:nth-child(3)")

# %%
stock
# Out:
# []

# %%
# 순수 텍스트 정보 담은 리스트 제작
stock_list = []

for i in range(len(singe)) :
    singer_list.append(singer[i].text)
    song_list.append(song[i].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 4
#       1 # 순수 텍스트 정보 담은 리스트 제작
#       2 stock_list = []
# ----> 4 for i in range(len(singe)) :
#       5     singer_list.append(singer[i].text)
#       6     song_list.append(song[i].text)
#
# NameError: name 'singe' is not defined

# %%
###다시!!!

#1. 필요한 라이브러리 import
import requests as req
from bs4 import BeautifulSoup as bs

# %%
# 2. 특정 웹페이지의 정보를 가져오라고 요청
page = req.get("https://finance.naver.com/sise/sise_market_sum.naver")

# %%
# 3. 응답된 데이터가 많아요 -> html내용만 필요하다
page.text
# Out:
# '\n\n\n\n\n\n\n<!--  global include -->\n\n\t\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t<title>시가총액 : 네이버페이 증권</title>\n\t\t\t\n\t\t\n\t\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta name="apple-mobile-web-app-title" content="네이버페이 증권" />\n\n\n\n\n\n\t\n    \n        <meta property="og:url" content="http://finance.naver.com/sise/sise_market_sum.naver"/>\n        \n\t\t\t\n\t\t    \n\t\t    \t<meta property="og:title" content="시가총액 : 네이버페이 증권"/>\n\t\t     \n\t\t\n\t\t\n\t\t\t\n\t\t\t   <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>\n\t\t    \n\t\t    \n\t\t\n\t\t \n\t\t\t\n\t\t\t    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t    \n\t\t    \n\t\t\n    \n\n<meta property="og:type" conten
# ...

# %%
# 4. 받아온 html은 거대한 String... -> 파싱
soup = bs( page.text,"lxml")

# %%
soup
# Out:
# <!--  global include --><html lang="ko">
# <head>
# <title>시가총액 : 네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title"/>
# <meta content="http://finance.naver.com/sise/sise_market_sum.naver" property="og:url"/>
# <meta content="시가총액 : 네이버페이 증권" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# ...

# %%
# 5. 많은 태그들을 가지고 있는 상태
title = soup.select("a.tltle")

# %%
title
# Out:
# [<a class="tltle" href="/item/main.naver?code=005930">삼성전자</a>,
#  <a class="tltle" href="/item/main.naver?code=000660">SK하이닉스</a>,
#  <a class="tltle" href="/item/main.naver?code=373220">LG에너지솔루션</a>,
#  <a class="tltle" href="/item/main.naver?code=207940">삼성바이오로직스</a>,
#  <a class="tltle" href="/item/main.naver?code=005380">현대차</a>,
#  <a class="tltle" href="/item/main.naver?code=005935">삼성전자우</a>,
#  <a class="tltle" href="/item/main.naver?code=012450">한화에어로스페이스</a>,
#  <a class="tltle" href="/item/main.naver?code=068270">셀트리온</a>,
#  <a class="tltle" href="/item/main.naver?code=000270">기아</a>,
#  <a class="tltle" href="/item/main.naver?code=329180">HD현대중공업</a>,
#  <a class="tltle" href="/item/main.naver?code=105560">KB금융</a>,
#  <a class="tltle" href="/item/main.naver?code=035420">NAVER</a>,
#  <a class="tltle" href="/item/main.naver?code=042660">한화오션</a>,
#  <a class="tltle" href="/item/main.naver?code=055550">신한지주</a>,
# ...

# %%
# 6. 특정 선택자에 해당하는 요소들만 빼서 리스트화
title[0].text
# Out:
# '삼성전자'

# %%
title_list = []
for i in title :
    print(i.text)
    title_list.append(i.text)
# Out:
# 삼성전자
# SK하이닉스
# LG에너지솔루션
# 삼성바이오로직스
# 현대차
# 삼성전자우
# 한화에어로스페이스
# 셀트리온
# 기아
# HD현대중공업
# KB금융
# NAVER
# 한화오션
# 신한지주
# 현대모비스
# POSCO홀딩스
# 메리츠금융지주
# 삼성물산
# 크래프톤
# 카카오
# HMM
# 삼성화재
# 하나금융지주
# HD한국조선해양
# 삼성생명
# LG화학
# 한국전력
# 두산에너빌리티
# SK이노베이션
# 고려아연
# KT&G
# 삼성중공업
# 삼성SDI
# 우리금융지주
# SK텔레콤
# KT
# LG전자
# 현대로템
# HD현대일렉트릭
# 기업은행
# SK스퀘어
# 포스코퓨처엠
# LG
# 카카오뱅크
# 포스코인터내셔널
# 하이브
# 유한양행
# 삼성전기
# 삼성에스디에스
# SK

# %%
price = soup.select("a.number")
price
# Out:
# []

# %%
title_list = []
for i in title :
    print(i.text)
    title_list.append(i.text)
# Out:
# 삼성전자
# SK하이닉스
# LG에너지솔루션
# 삼성바이오로직스
# 현대차
# 삼성전자우
# 한화에어로스페이스
# 셀트리온
# 기아
# HD현대중공업
# KB금융
# NAVER
# 한화오션
# 신한지주
# 현대모비스
# POSCO홀딩스
# 메리츠금융지주
# 삼성물산
# 크래프톤
# 카카오
# HMM
# 삼성화재
# 하나금융지주
# HD한국조선해양
# 삼성생명
# LG화학
# 한국전력
# 두산에너빌리티
# SK이노베이션
# 고려아연
# KT&G
# 삼성중공업
# 삼성SDI
# SK텔레콤
# 우리금융지주
# KT
# LG전자
# 현대로템
# 기업은행
# HD현대일렉트릭
# SK스퀘어
# 포스코퓨처엠
# 카카오뱅크
# LG
# 포스코인터내셔널
# 하이브
# 유한양행
# 삼성전기
# 삼성에스디에스
# SK

# %%
price_list = []
for j in price:
    print(j.text)
    price_list.append(j.text)

# %%
for i in range(len(title)) :
    title_list.append(title[i].text)
    price_list.append(title[i].text)

# %%
price_list
# Out:
# ['삼성전자',
#  'SK하이닉스',
#  'LG에너지솔루션',
#  '삼성바이오로직스',
#  '현대차',
#  '삼성전자우',
#  '한화에어로스페이스',
#  '셀트리온',
#  '기아',
#  'HD현대중공업',
#  'KB금융',
#  'NAVER',
#  '한화오션',
#  '신한지주',
#  '현대모비스',
#  'POSCO홀딩스',
#  '메리츠금융지주',
#  '삼성물산',
#  '크래프톤',
#  '카카오',
#  'HMM',
#  '삼성화재',
#  '하나금융지주',
#  'HD한국조선해양',
#  '삼성생명',
#  'LG화학',
#  '한국전력',
#  '두산에너빌리티',
#  'SK이노베이션',
#  '고려아연',
#  'KT&G',
#  '삼성중공업',
#  '삼성SDI',
#  '우리금융지주',
#  'SK텔레콤',
#  'KT',
#  'LG전자',
#  '현대로템',
#  'HD현대일렉트릭',
#  '기업은행',
#  'SK스퀘어',
#  '포스코퓨처엠',
#  'LG',
#  '카카오뱅크',
#  '포스코인터내셔널',
#  '하이브',
#  '유한양행',
#  '삼성전기',
#  '삼성에스디에스',
#  'SK']

# %%
import nbformat

# 1. 노트북 파일 열기 (파일 경로는 실제로 존재하는 걸로!)
with open("example.ipynb", "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

# 2. 셀 내용 출력
for i in range(len(nb.cells)):
    print(nb.cells[i].source)
